# %%
import pandas as pd
df = pd.read_csv("C:/Users/sidha/Downloads/retail_data/retail_store_sales.csv")

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3              NaN
# ...

# %%
df.shape
# Out:
# (12575, 11)

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Customer ID', 'Category', 'Item', 'Price Per Unit',
#        'Quantity', 'Total Spent', 'Payment Method', 'Location',
#        'Transaction Date', 'Discount Applied'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64

# %%
df[df['Price Per Unit'].isnull()][['Quantity', 'Total Spent']].isnull().sum()
# Out:
# Quantity       0
# Total Spent    0
# dtype: int64

# %%
df[df['Quantity'].isnull()][['Total Spent', 'Price Per Unit']].isnull().sum()
# Out:
# Total Spent       604
# Price Per Unit      0
# dtype: int64

# %%
df[df['Quantity'].isnull()]['Price Per Unit'].isnull().sum()
# Out:
# np.int64(0)

# %%
(df['Quantity'].isnull() & df['Total Spent'].notnull()).sum()
# Out:
# np.int64(0)

# %%
(df['Quantity'].notnull() & df['Total Spent'].isnull()).sum()
# Out:
# np.int64(0)

# %%
df[df['Price Per Unit'].isnull()][['Quantity', 'Total Spent']].notnull().sum()
# Out:
# Quantity       609
# Total Spent    609
# dtype: int64

# %%
df['Price Per Unit'].isnull().sum()
# Out:
# np.int64(609)

# %%
mask = df['Price Per Unit'].isnull()
df.loc[mask, 'Price Per Unit'] = df.loc[mask, 'Total Spent'] / df.loc[mask, 'Quantity']

# %%
df['Price Per Unit'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit         0
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64

# %%
df[df['Item'].isnull()]['Category'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Item'] = df['Item'].fillna('Unknown Item')

# %%
df['Item'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['is_incomplete'] = df['Quantity'].isnull()

# %%
df['is_incomplete'].sum()
# Out:
# np.int64(604)

# %%
df.head(10)
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# 5    TXN_7482416     CUST_09     Patisserie  Unknown Item            20.0
# 6    TXN_3652209     CUST_07           Food   Item_1_FOOD             5.0
# 7    TXN_1372952     CUST_21      Furniture  Unknown Item            33.5
# 8    TXN_9728486     CUST_23      Furniture   Item_16_FUR            27.5
# 9    TXN_2722661     CUST_25       Butchers   Item_22_BUT            36.5
#
#    Quantity  Total Spent  Payment Method  Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet    Online       2024-04-08
# ...

# %%
df['Discount Applied'].unique()
# Out:
# array([True, False, nan], dtype=object)

# %%
df['discount_unrecorded'] = df['Discount Applied'].isnull()

# %%
df.head(10)
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# 5    TXN_7482416     CUST_09     Patisserie  Unknown Item            20.0
# 6    TXN_3652209     CUST_07           Food   Item_1_FOOD             5.0
# 7    TXN_1372952     CUST_21      Furniture  Unknown Item            33.5
# 8    TXN_9728486     CUST_23      Furniture   Item_16_FUR            27.5
# 9    TXN_2722661     CUST_25       Butchers   Item_22_BUT            36.5
#
#    Quantity  Total Spent  Payment Method  Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet    Online       2024-04-08
# ...

# %%
df['Discount Applied'] = df['Discount Applied'].fillna(False)

# %%
df['Discount Applied'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.rename(columns={'is_incomplete': 'missing_quantity_and_total'}, inplace=True)

# %%
df.head(10)
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# 5    TXN_7482416     CUST_09     Patisserie  Unknown Item            20.0
# 6    TXN_3652209     CUST_07           Food   Item_1_FOOD             5.0
# 7    TXN_1372952     CUST_21      Furniture  Unknown Item            33.5
# 8    TXN_9728486     CUST_23      Furniture   Item_16_FUR            27.5
# 9    TXN_2722661     CUST_25       Butchers   Item_22_BUT            36.5
#
#    Quantity  Total Spent  Payment Method  Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet    Online       2024-04-08
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Transaction ID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Transaction ID                    str
# Customer ID                       str
# Category                          str
# Item                              str
# Price Per Unit                float64
# Quantity                      float64
# Total Spent                   float64
# Payment Method                    str
# Location                          str
# Transaction Date                  str
# Discount Applied               object
# missing_quantity_and_total       bool
# discount_unrecorded              bool
# dtype: object

# %%
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'])

# %%
df.dtypes
# Out:
# Transaction ID                           str
# Customer ID                              str
# Category                                 str
# Item                                     str
# Price Per Unit                       float64
# Quantity                             float64
# Total Spent                          float64
# Payment Method                           str
# Location                                 str
# Transaction Date              datetime64[us]
# Discount Applied                      object
# missing_quantity_and_total              bool
# discount_unrecorded                     bool
# dtype: object

# %%
df.head(10)
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# 5    TXN_7482416     CUST_09     Patisserie  Unknown Item            20.0
# 6    TXN_3652209     CUST_07           Food   Item_1_FOOD             5.0
# 7    TXN_1372952     CUST_21      Furniture  Unknown Item            33.5
# 8    TXN_9728486     CUST_23      Furniture   Item_16_FUR            27.5
# 9    TXN_2722661     CUST_25       Butchers   Item_22_BUT            36.5
#
#    Quantity  Total Spent  Payment Method  Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet    Online       2024-04-08
# ...

# %%
df['Discount Applied'] = df['Discount Applied'].astype(bool)

# %%
df.dtypes
# Out:
# Transaction ID                           str
# Customer ID                              str
# Category                                 str
# Item                                     str
# Price Per Unit                       float64
# Quantity                             float64
# Total Spent                          float64
# Payment Method                           str
# Location                                 str
# Transaction Date              datetime64[us]
# Discount Applied                        bool
# missing_quantity_and_total              bool
# discount_unrecorded                     bool
# dtype: object

# %%
mismatch = df[df['missing_quantity_and_total'] == False].copy()
mismatch['calculated_total'] = mismatch['Price Per Unit'] * mismatch['Quantity']
(mismatch['calculated_total'].round(2) != mismatch['Total Spent'].round(2)).sum()
# Out:
# np.int64(0)

# %%
df.to_csv('cleaned_sales.csv', index=False)
